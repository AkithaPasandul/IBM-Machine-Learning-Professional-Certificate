# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Machine Learning Foundation
#
# ## Course 5, Part g: RNN DEMO

# %% [markdown]
# ## Using RNNs to classify sentiment on IMDB data
# For this exercise, we will train a "vanilla" RNN to predict the sentiment on IMDB reviews.  Our data consists of 25000 training sequences and 25000 test sequences.  The outcome is binary (positive/negative) and both outcomes are equally represented in both the training and the test set.
#
# Keras provides a convenient interface to load the data and immediately encode the words into integers (based on the most common words).  This will save us a lot of the drudgery that is usually involved when working with raw text.
#
# We will walk through the preparation of the data and the building of an RNN model.  Then it will be your turn to build your own models (and prepare the data how you see fit).

# %%
# %%capture
# !pip install --upgrade tensorflow

# %%
from tensorflow import keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import SimpleRNN
from keras.datasets import imdb
from keras import initializers
# Out:
# 2025-03-19 15:14:20.969549: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-19 15:14:21.205885: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-19 15:14:21.216090: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-03-19 15:14:21.216152: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-03-19 15:14:22.127784: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2025-03-19 15:14:22.127906: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2025-03-19 15:14:22.127919: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 30  # maximum length of a sequence - truncate after this
batch_size = 32

# %%
## Load in the data.  The function automatically tokenizes the text into distinct integers
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# 25000 train sequences
# 25000 test sequences

# %%
# This pads (or truncates) the sequences so that they are of the maximum length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (25000, 30)
# x_test shape: (25000, 30)

# %%
x_train[123,:]  #Here's what an example sequence looks like
# Out:
# array([  219,   141,    35,   221,   956,    54,    13,    16,    11,
#         2714,    61,   322,   423,    12,    38,    76,    59,  1803,
#           72,     8, 10508,    23,     5,   967,    12,    38,    85,
#           62,   358,    99], dtype=int32)

# %% [markdown]
# ## Keras layers for (Vanilla) RNNs
#
# In this exercise, we will not use pre-trained word vectors.  Rather we will learn an embedding as part of the Neural Network.  This is represented by the Embedding Layer below.
#
# ### Embedding Layer
# `keras.layers.embeddings.Embedding(input_dim, output_dim, embeddings_initializer='uniform', embeddings_regularizer=None, activity_regularizer=None, embeddings_constraint=None, mask_zero=False, input_length=None)`
#
# - This layer maps each integer into a distinct (dense) word vector of length `output_dim`.
# - Can think of this as learning a word vector embedding "on the fly" rather than using an existing mapping (like GloVe)
# - The `input_dim` should be the size of the vocabulary.
# - The `input_length` specifies the length of the sequences that the network expects.
#
# ### SimpleRNN Layer
# `keras.layers.recurrent.SimpleRNN(units, activation='tanh', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, dropout=0.0, recurrent_dropout=0.0)`
#
# - This is the basic RNN, where the output is also fed back as the "hidden state" to the next iteration.
# - The parameter `units` gives the dimensionality of the output (and therefore the hidden state).  Note that typically there will be another layer after the RNN mapping the (RNN) output to the network output.  So we should think of this value as the desired dimensionality of the hidden state and not necessarily the desired output of the network.
# - Recall that there are two sets of weights, one for the "recurrent" phase and the other for the "kernel" phase.  These can be configured separately in terms of their initialization, regularization, etc.

# %%
## Let's build a RNN

rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence and embeds it in a 50-dimensional vector
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))
# Out:
# 2025-03-19 15:14:29.062594: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2025-03-19 15:14:29.062660: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-03-19 15:14:29.062691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterlab-akitha960): /proc/driver/nvidia/version does not exist
# 2025-03-19 15:14:29.063253: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Note that most of the parameters come from the embedding layer
model_rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 50)          1000000
#
#  simple_rnn (SimpleRNN)      (None, 5)                 280
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 1,000,286
# Trainable params: 1,000,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 38s 47ms/step - loss: 0.6727 - accuracy: 0.5919 - val_loss: 0.6267 - val_accuracy: 0.6603
# Epoch 2/10
# 782/782 [==============================] - 35s 45ms/step - loss: 0.5821 - accuracy: 0.6944 - val_loss: 0.5610 - val_accuracy: 0.7070
# Epoch 3/10
# 782/782 [==============================] - 38s 48ms/step - loss: 0.5165 - accuracy: 0.7464 - val_loss: 0.5232 - val_accuracy: 0.7334
# Epoch 4/10
# 782/782 [==============================] - 37s 48ms/step - loss: 0.4720 - accuracy: 0.7762 - val_loss: 0.4988 - val_accuracy: 0.7510
# Epoch 5/10
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4402 - accuracy: 0.7978 - val_loss: 0.4811 - val_accuracy: 0.7636
# Epoch 6/10
# 782/782 [==============================] - 37s 48ms/step - loss: 0.4169 - accuracy: 0.8129 - val_loss: 0.4765 - val_accuracy: 0.7682
# Epoch 7/10
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3999 - accuracy: 0.8209 - val_loss: 0.4624 - val_accuracy: 0.7764
# Epoch 8/10
# 782/782 [==============================] - 37s 48ms/step - loss: 0.3864 - accuracy: 0.8290 - val_loss: 0.4568 - val_accuracy: 0.7779
# Epoch 9/10
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3759 - accuracy: 0.8324 - val_loss: 0.4523 - val_accuracy: 0.7842
# Epoch 10/10
# 782/782 [==============================] - 38s 49ms/step - loss: 0.3673 - accuracy: 0.8382 - val_loss: 0.4507 - val_accuracy: 0.7859

# %%
score, acc = model_rnn.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 782/782 [==============================] - 7s 9ms/step - loss: 0.4507 - accuracy: 0.7859
# Test score: 0.4507269561290741
# Test accuracy: 0.7859200239181519

# %% [markdown]
# ## Exercise
#
# In this exercise, we will illustrate:
# - Preparing the data to use sequences of length 80 rather than length 30.  Does it improve the performance?
# - Trying different values of the "max_features".  Does this  improve the performance?
# - Trying smaller and larger sizes of the RNN hidden dimension.  How does it affect the model performance?  How does it affect the run time?

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 78s 99ms/step - loss: 0.6738 - accuracy: 0.5881 - val_loss: 0.6294 - val_accuracy: 0.6750
# Epoch 2/10
# 782/782 [==============================] - 86s 110ms/step - loss: 0.5634 - accuracy: 0.7279 - val_loss: 0.5308 - val_accuracy: 0.7392
# Epoch 3/10
# 782/782 [==============================] - 77s 99ms/step - loss: 0.4670 - accuracy: 0.7853 - val_loss: 0.4855 - val_accuracy: 0.7612
# Epoch 4/10
# 782/782 [==============================] - 77s 98ms/step - loss: 0.4138 - accuracy: 0.8158 - val_loss: 0.4538 - val_accuracy: 0.7836
# Epoch 5/10
# 782/782 [==============================] - 76s 97ms/step - loss: 0.3796 - accuracy: 0.8346 - val_loss: 0.4374 - val_accuracy: 0.7958
# Epoch 6/10
# 782/782 [==============================] - 76s 98ms/step - loss: 0.3529 - accuracy: 0.8503 - val_loss: 0.4229 - val_accuracy: 0.8039
# Epoch 7/10
# 782/782 [==============================] - 75s 96ms/step - loss: 0.3315 - accuracy: 0.8599 - val_loss: 0.4142 - val_accuracy: 0.8083
# Epoch 8/10
# 782/782 [==============================] - 78s 99ms/step - loss: 0.3136 - accuracy: 0.8698 - val_loss: 0.4067 - val_accuracy: 0.8156
# Epoch 9/10
# 782/782 [==============================] - 76s 97ms/step - loss: 0.2984 - accuracy: 0.8767 - val_loss: 0.3915 - val_accuracy: 0.8234
# Epoch 10/10
# 782/782 [==============================] - 78s 100ms/step - loss: 0.2855 - accuracy: 0.8840 - val_loss: 0.3916 - val_accuracy: 0.8267

# %%
max_features = 5000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 20
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 63s 79ms/step - loss: 0.6755 - accuracy: 0.5746 - val_loss: 0.6271 - val_accuracy: 0.6619
# Epoch 2/10
# 782/782 [==============================] - 64s 82ms/step - loss: 0.5622 - accuracy: 0.7161 - val_loss: 0.5228 - val_accuracy: 0.7423
# Epoch 3/10
# 782/782 [==============================] - 64s 82ms/step - loss: 0.4806 - accuracy: 0.7731 - val_loss: 0.4843 - val_accuracy: 0.7670
# Epoch 4/10
# 782/782 [==============================] - 66s 85ms/step - loss: 0.4378 - accuracy: 0.7973 - val_loss: 0.4599 - val_accuracy: 0.7782
# Epoch 5/10
# 782/782 [==============================] - 66s 84ms/step - loss: 0.4080 - accuracy: 0.8152 - val_loss: 0.4373 - val_accuracy: 0.7952
# Epoch 6/10
# 782/782 [==============================] - 65s 84ms/step - loss: 0.3845 - accuracy: 0.8307 - val_loss: 0.4215 - val_accuracy: 0.8036
# Epoch 7/10
# 782/782 [==============================] - 65s 84ms/step - loss: 0.3658 - accuracy: 0.8395 - val_loss: 0.4077 - val_accuracy: 0.8123
# Epoch 8/10
# 782/782 [==============================] - 65s 83ms/step - loss: 0.3511 - accuracy: 0.8476 - val_loss: 0.3981 - val_accuracy: 0.8157
# Epoch 9/10
# 782/782 [==============================] - 66s 85ms/step - loss: 0.3384 - accuracy: 0.8546 - val_loss: 0.3892 - val_accuracy: 0.8210
# Epoch 10/10
# 782/782 [==============================] - 65s 83ms/step - loss: 0.3278 - accuracy: 0.8608 - val_loss: 0.3830 - val_accuracy: 0.8260

# %%
# Out of curiosity, run for 10 more epochs
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 65s 84ms/step - loss: 0.3189 - accuracy: 0.8634 - val_loss: 0.3750 - val_accuracy: 0.8314
# Epoch 2/10
# 782/782 [==============================] - 65s 84ms/step - loss: 0.3115 - accuracy: 0.8680 - val_loss: 0.3892 - val_accuracy: 0.8248
# Epoch 3/10
# 782/782 [==============================] - 67s 85ms/step - loss: 0.3059 - accuracy: 0.8700 - val_loss: 0.3738 - val_accuracy: 0.8314
# Epoch 4/10
# 782/782 [==============================] - 64s 82ms/step - loss: 0.3009 - accuracy: 0.8736 - val_loss: 0.3670 - val_accuracy: 0.8367
# Epoch 5/10
# 782/782 [==============================] - 62s 80ms/step - loss: 0.2966 - accuracy: 0.8751 - val_loss: 0.3685 - val_accuracy: 0.8355
# Epoch 6/10
# 782/782 [==============================] - 65s 83ms/step - loss: 0.2928 - accuracy: 0.8774 - val_loss: 0.3639 - val_accuracy: 0.8392
# Epoch 7/10
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2893 - accuracy: 0.8798 - val_loss: 0.3664 - val_accuracy: 0.8384
# Epoch 8/10
# 782/782 [==============================] - 62s 80ms/step - loss: 0.2868 - accuracy: 0.8814 - val_loss: 0.3651 - val_accuracy: 0.8384
# Epoch 9/10
# 782/782 [==============================] - 61s 79ms/step - loss: 0.2842 - accuracy: 0.8824 - val_loss: 0.3618 - val_accuracy: 0.8406
# Epoch 10/10
# 782/782 [==============================] - 62s 79ms/step - loss: 0.2815 - accuracy: 0.8836 - val_loss: 0.3645 - val_accuracy: 0.8402

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation
